# %%
import pandas as pd
import requests
import io
from matplotlib import pyplot as plt

# %%
# %%bash
# pip install geojson
# Out:
# -bash: line 1: pip: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-ed19c60fe655> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'pip install geojson\n')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2321             magic_arg_s = self.var_expand(line, stack_depth)
#    2322             with self.builtin_trap:
# -> 2323                 result = fn(magic_arg_s, cell)
#    2324             return result
#    2325
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-110> in shebang(self, line, cell)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'pip install geojson\n'' returned non-zero exit status 127.

# %%
csv_url = 'https://data.honolulu.gov/resource/2hpk-5j7p.csv' #building permits from 2005 to 2018

# This is taken from a github for now: https://github.com/codeforamerica/click_that_hood/blob/master/public/data/honolulu.geojson
geojson_url = 'https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/honolulu.geojson'

# %%
web_pull_csv = requests.get(csv_url)

# %%
# This takes the web response from the api, looks at the content and decodes it using io, and loads it into a pandas dataframe
web_pull_cotnent = web_pull_csv.content
business_license_05_to_18 = pd.read_csv(io.StringIO(web_pull_cotnent.decode('utf-8')))
data = business_license_05_to_18 # renaming data for short name for now, just for ease

# %%
data.head()
# Out:
#    :@computed_region_7asa_3qps  acceptedvalue accessorydwellingunitadu  \
# 0                          NaN         2000.0                        N
# 1                          NaN         2270.9                        N
# 2                          NaN         1500.0                        N
# 3                          NaN         3500.0                        N
# 4                          NaN         1000.0                        N
#
#   addition alteration                  applicant  bpfeecalculation  \
# 0        N          N             DUNG, AH CHONG              51.0
# 1        N          N     ENERGY INDUSTRIES, LLC              57.0
# 2        N          N   Alternative Electric LLP              41.0
# 3        N          N  TED'S WIRING SERVICE, LTD              81.0
# 4        N          N              LUZ BUNGCAYAO              31.0
#
#    bpfeescollected  buildingpermitno buildingpermittype  \
# 0             51.0            597748                NaN
# 1             57.0            611014                NaN
# 2             41.0            662175                NaN
# 3             81.0            634438                NaN
# 4             31.0            641747                NaN
#
#            ...           solarvpinstallation stateproject  \
# 0          ...                             N          NaN
# 1          ...                             N          NaN
# 2          ...                             N          NaN
# 3          ...                             N          NaN
# 4          ...                             N           No
#
#            statusdescription statusid       structurecode       tmk  \
# 0  Permit application closed      110       97 - PLUMBING  44007027
# 1  Permit application closed      110     96 - ELECTRICAL  26024097
# 2  Permit application closed      110     96 - ELECTRICAL  92025084
# 3  Permit application closed      110     96 - ELECTRICAL  14013024
# 4  Permit application closed      110  51 - SINGLE FAMILY  18012030
#
#    tmklookup totalfloorarea  typesofconstructionactual typesofconstructionmin
# 0  44007027-            NaN                        NaN                    NaN
# 1  26024097-            NaN                        NaN                    NaN
# 2  92025084-            NaN                         VN                     VN
# 3  14013024-            NaN                         VN                     VN
# 4  18012030-            NaN                         VN                     VN
#
# [5 rows x 81 columns]

# %%
data.describe()
# Out:
#        :@computed_region_7asa_3qps  acceptedvalue  bpfeecalculation  \
# count                          0.0   1.000000e+03       1000.000000
# mean                           NaN   1.927500e+04        299.078300
# std                            NaN   5.888601e+04        614.898415
# min                            NaN   7.500000e+01         15.000000
# 25%                            NaN   1.500000e+03         41.000000
# 50%                            NaN   3.800000e+03         85.000000
# 75%                            NaN   1.500000e+04        311.000000
# max                            NaN   1.043700e+06       7613.000000
#
#        bpfeescollected  buildingpermitno  curbingtypes  \
# count      1000.000000       1000.000000           0.0
# mean        250.919300     687633.336000           NaN
# std         595.350294      79494.176462           NaN
# min           0.000000     503916.000000           NaN
# 25%          41.000000     625517.250000           NaN
# 50%          61.000000     686834.000000           NaN
# 75%         191.000000     752469.000000           NaN
# max        7613.000000     822720.000000           NaN
#
#        electrical_vehicle_charger  estimatedvalueofwork  existingfloorarea  \
# count                         0.0          1.000000e+03           6.000000
# mean                          NaN          1.744079e+04        5248.333333
# std                           NaN          5.881568e+04       10302.542321
# min                           NaN          0.000000e+00           0.000000
# 25%                           NaN          1.500000e+03         359.500000
# 50%                           NaN          3.572930e+03        1599.000000
# 75%                           NaN          1.407000e+04        2009.000000
# max                           NaN          1.310000e+06       26200.000000
#
#        finalstories       ...        location_1_zip  newfloorarea  \
# count    146.000000       ...                   0.0    101.000000
# mean       1.856164       ...                   NaN    938.519307
# std        4.034318       ...                   NaN   1164.871836
# min        0.000000       ...                   NaN      0.000000
# 25%        1.000000       ...                   NaN    194.000000
# 50%        1.000000       ...                   NaN    478.100000
# 75%        2.000000       ...                   NaN   1271.000000
# max       37.000000       ...                   NaN   6076.000000
#
#        numroomsadd  numroomsdel  numunitsadd  numunitsdel      objectid  \
# count          5.0          1.0   216.000000    40.000000  1.000000e+03
# mean           0.0          0.0     0.060185     0.775000  4.158071e+07
# std            0.0          NaN     0.238382     0.422902  1.399771e+07
# min            0.0          0.0     0.000000     0.000000  1.100308e+07
# 25%            0.0          0.0     0.000000     1.000000  2.786035e+07
# 50%            0.0          0.0     0.000000     1.000000  4.444504e+07
# 75%            0.0          0.0     0.000000     1.000000  5.305640e+07
# max            0.0          0.0     1.000000     1.000000  6.390947e+07
#
#        sidewalktypes     statusid  totalfloorarea
# count            0.0  1000.000000       19.000000
# mean             NaN   204.875000     3540.168421
# std              NaN   247.505289     5672.037379
# min              NaN   110.000000        0.000000
# 25%              NaN   110.000000     1683.000000
# 50%              NaN   110.000000     2286.000000
# 75%              NaN   110.000000     3602.500000
# max              NaN  1025.000000    26200.000000
#
# [8 rows x 24 columns]

# %%
data.hist('location_1_zip').show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-83ed1b8222ee> in <module>
# ----> 1 data.hist('location_1_zip').show
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
years = []
year_index = 0
for year_index in range(len(data)):
    year = data['issuedate'][year_index][0:4]
    years.append(year)

# %%
from collections import Counter
Counter(years)

fig = plt.figure(figsize=(50,40))
plt.hist(years)
# Out:
# (array([ 98., 119., 133., 163.,  96., 128., 117.,  91.,  39.,  16.]),
#  array([ 0. ,  1.8,  3.6,  5.4,  7.2,  9. , 10.8, 12.6, 14.4, 16.2, 18. ]),
#  <a list of 10 Patch objects>)

# %%
# %matplotlib inline
import geojson
from descartes import PolygonPatch
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")
from shapely.geometry import Polygon
import math
import numpy as np
import requests
import pandas as pd


def base_map(fp):
    #fp = "..\\..\\..\\Geographies\GeoJson\\Census_Tracts_in_2010.geojson"
    with open(fp) as f:
        gj = geojson.load(f)
    BLUE = '#6699cc'

    fig = plt.figure(num=None, figsize=(20, 16), dpi=80, facecolor='w', edgecolor='k')
    fig.show()
    return(fig)


fp = "Census_Tracts_in_2010.geojson"

a= base_map(fp)
a.show()

BLUE = '#6699cc'
fig = plt.figure() 
ax = fig.gca() 
ax.add_patch(PolygonPatch(poly, fc=BLUE, ec=BLUE, alpha=0.5, zorder=2 ))
ax.axis('scaled')
plt.show()

# %%
fp = "Census_Tracts_in_2010.geojson"
with open(fp) as f:
    gj = geojson.load(f)
gjb = gj['features']

poly = gjb[0]['geometry']

# %%
# https://gis.stackexchange.com/questions/93136/how-to-plot-geo-data-using-matplotlib-python
type(a)
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
import matplotlib.pyplot as plt 
from descartes import PolygonPatch
BLUE = '#6699cc'
fig = plt.figure() 
ax = fig.gca() 
ax.add_patch(PolygonPatch(poly, fc=BLUE, ec='#000000', alpha=0.5, zorder=2 ))
ax.axis('scaled')
plt.show()

# %%
gjb[0]['geometry'].keys()
# Out:
# dict_keys(['type', 'coordinates'])

# %%
import matplotlib.pyplot as plt 
coords = poly['coordinates']

x = [i for i,j in coords[0]]
y = [j for i,j in coords[0]]

ax = fig.gca() 
ax.plot(x,y)
ax.axis('scaled')
plt.show()

# %%
data['estimatedvalueofwork']
# Out:
# 0        2000.00
# 1        2270.90
# 2        1500.00
# 3        3500.00
# 4         700.00
# 5        1500.00
# 6       15000.00
# 7       15000.00
# 8        5000.00
# 9        2950.00
# 10      19000.00
# 11      17000.00
# 12       9000.00
# 13      15000.00
# 14       2875.00
# 15       3300.00
# 16       1500.00
# 17       1500.00
# 18       1500.00
# 19      24000.00
# 20       1500.00
# 21       5000.00
# 22       1500.00
# 23       5000.00
# 24       5000.00
# 25      21600.00
# 26       1500.00
# 27       1800.00
# 28      29000.00
# 29        500.00
#          ...
# 970     27000.00
# 971      1800.00
# 972      3800.00
# 973      4200.00
# 974      4000.00
# 975      1500.00
# 976      1500.00
# 977      4000.00
# 978    100000.00
# 979      2000.00
# 980      3800.00
# 981     27369.88
# 982     29971.00
# 983      5000.00
# 984      1000.00
# 985     27000.00
# 986      3800.00
# 987      1500.00
# 988     29794.17
# 989      1500.00
# 990     12000.00
# 991     22879.00
# 992     18000.00
# 993     12000.00
# 994      1700.00
# 995      5000.00
# 996     36100.00
# 997      6000.00
# 998     26800.00
# 999       300.00
# Name: estimatedvalueofwork, Length: 1000, dtype: float64
